# %%
using Plots
theme(:dark)

# %%
using Distributions

# %% [markdown]
# # zad 1

# %% [markdown]
# ## Rozkład wykładniczy

# %% [markdown]
# $$F_X(t)=1-e^{-\frac{1}{\lambda} x}$$
# więc
# $$ F_X^{-1}(t) = -\lambda\ln(1-t) $$

# %%
f(x,lambda)=-log(1-x)*lambda
# Out:
# f (generic function with 1 method)

# %%
lambda=2
lambda=1/lambda
# Out:
# 0.5

# %%
X=Exponential(1/lambda)
# Out:
# Exponential{Float64}(θ=2.0)

# %%
plot(0:0.01:6,[cdf(X, i) for i in 0:0.01:6])

# %%
plot!([f(x, 1/lambda) for x in 0:0.001:1],0:0.001:1)

# %%
maximum(abs(f(x,1/lambda)-quantile(X,x)) for x in 0:0.01:0.99)
# Out:
# 2.220446049250313e-16

# %%
# Out:
# 10-element Vector{Float64}:
#  0.22782046344067905
#  0.4478216820007013
#  0.20233755525629563
#  0.17822096334329376
#  0.593517176375073
#  0.353327712726838
#  0.6241395768346122
#  3.714625816702584
#  0.7411948460686177
#  0.32026360148827265

# %%
histogram(rand(X,10^5), normed=true, xlims=(0,6))

# %%
histogram!([f(rand(),1/lambda) for i in 1:1e5], normed=true, xlim=(0,6), opacity=0.6)

# %% [markdown]
# ## Normalny

# %%
mu=2
sigma=3
# Out:
# 3

# %%
Y=Normal(mu,sigma)
# Out:
# Normal{Float64}(μ=2.0, σ=3.0)

# %%
# Out:
# MethodError: no method matching pdf(::Normal{Float64})
# Closest candidates are:
#   pdf(::Normal, ::Real) at C:\Users\Kacper\.julia\packages\Distributions\Xrm9e\src\univariate\continuous\normal.jl:123
#   pdf(::UnivariateDistribution{S} where S<:ValueSupport, ::Real) at C:\Users\Kacper\.julia\packages\Distributions\Xrm9e\src\univariates.jl:322
#   pdf(::UnivariateDistribution{S} where S<:ValueSupport, ::AbstractArray) at deprecated.jl:70
#   ...
#
# Stacktrace:
#  [1] top-level scope
#    @ In[73]:1
#  [2] eval
#    @ .\boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base .\loading.jl:1094
