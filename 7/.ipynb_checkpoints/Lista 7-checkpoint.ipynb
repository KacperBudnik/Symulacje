# %%
using Plots

# %%
T=10
λ=1/2
t() = -1/λ*log(rand())
n=Int(1e3)
Δ=T/n
;

# %% [markdown]
# # Zad 1

# %%
a=[t()]
# Out:
# 1-element Vector{Float64}:
#  3.5355178348545753

# %%
while a[end]<T
    push!(a,t()+a[end])
end

# %%
a
# Out:
# 5-element Vector{Float64}:
#   3.5355178348545753
#   3.635908287808827
#   4.932784212997969
#   9.612536942602155
#  11.513859734804024

# %%
plot(a,0:length(a)-1, linetype=:steppre, leg=false)

# %%
b=zeros(n);

# %%
j=1
for i in 1:n
    while i*Δ>=a[j]
        j+=1
    end
    b[i]=j
end
    
b=b.-1;

# %%
scatter!(0:Δ:T-Δ,b)

# %%
scatter!(xlim=(0,10))

# %% [markdown]
# # Zad 2

# %% [markdown]
# # Zad 3

# %% [markdown]
# # Nic
